# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiz121/Supply-Chain/blob/main/inventory_management_sytem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **Loading Data**

# %%
file_path = "/content/Sugarcane_Supply_Chain_2021_2024.csv"
data = pd.read_csv(file_path)

# %% [markdown]
# **Function to analyze inventory and monthly input/output**

# %%
def analyze_inventory_and_flow(data):
    data['Storage Capacity (tons)'] = data['Storage Capacity (tons)'].fillna(0)
    data['Storage Occupied (%)'] = data['Storage Occupied (%)'].fillna(0)
    data['Export Volume (tons)'] = data['Export Volume (tons)'].fillna(0)
    data['Current Inventory (tons)'] = data['Storage Capacity (tons)'] * (data['Storage Occupied (%)'] / 100)
    data['Date'] = pd.to_datetime(data['Date'])
    data['Year-Month'] = data['Date'].dt.to_period('M')
    monthly_summary = data.groupby('Year-Month').agg({
        'Export Volume (tons)': 'sum',
        'Current Inventory (tons)': 'sum',
    }).reset_index()
    monthly_summary.rename(columns={
        'Export Volume (tons)': 'Total Monthly Output (tons)',
        'Current Inventory (tons)': 'Total Monthly Inventory (tons)'
    }, inplace=True)

    alerts = []
    for index, row in data.iterrows():
        location = row['Location']
        occupied_percent = row['Storage Occupied (%)']
        capacity = row['Storage Capacity (tons)']

        if capacity > 0:
            if occupied_percent > 80:
                alerts.append({
                    "Date": row['Date'].strftime('%Y-%m-%d'),
                    "Location": location,
                    "Alert Type": "HIGH UTILIZATION",
                    "Reason": f"{occupied_percent:.2f}% storage occupied."
                })
            elif occupied_percent < 20:
                alerts.append({
                    "Date": row['Date'].strftime('%Y-%m-%d'),
                    "Location": location,
                    "Alert Type": "LOW UTILIZATION",
                    "Reason": f"{occupied_percent:.2f}% storage occupied."
                })

    alerts_df = pd.DataFrame(alerts)
    return monthly_summary, alerts_df

# %%
monthly_summary, alerts_df = analyze_inventory_and_flow(data)

# %%
print("== Monthly Input/Output Summary ==")
print(monthly_summary)
# Out:
# == Monthly Input/Output Summary ==
#    Year-Month  Total Monthly Output (tons)  Total Monthly Inventory (tons)
# 0     2021-01                     101257.0                       174161.65
# 1     2021-02                     124122.0                       187864.48
# 2     2021-03                      73952.0                       267897.69
# 3     2021-04                      92302.0                       342530.04
# 4     2021-05                      44002.0                       183359.61
# 5     2021-06                      54520.0                       230418.90
# 6     2021-07                      96565.0                       303390.80
# 7     2021-08                      54260.0                       249598.22
# 8     2021-09                      61727.0                       209479.61
# 9     2021-10                      69509.0                       357328.09
# 10    2021-11                      37183.0                        72037.49
# 11    2021-12                      40414.0                       260656.50
# 12    2022-01                      57199.0                       225671.43
# 13    2022-02                      89476.0                       233786.93
# 14    2022-03                      32057.0                       223822.97
# 15    2022-04                      78620.0                       229843.62
# 16    2022-05                      63701.0                       310392.81
# 17    2022-06                      46254.0                       220045.75
# 18    2022-07                      50204.0                       194050.64
# 19    2022-08                      82644.0                       300965.52
# 20    2022-09                      41594.0                       207348.94
# 21    2022-10                      74399.0                       361947.00
# 22    2022-11                      84275.0                       256315.81
# 23    2022-12                      82402.0                       383686.84
# 24    2023-01                      89103.0                       297478.42
# 25    2023-02                      67619.0                       151572.05
# 26    2023-03                      96296.0                       185087.00
# 27    2023-04                      86593.0                        49291.47
# 28    2023-05                      79099.0                       135873.05
# 29    2023-06                      75291.0                       125470.38
# 30    2023-07                      68717.0                       117107.72
# 31    2023-08                      15086.0                        59977.39
# 32    2023-09                      34685.0                       323383.78
# 33    2023-10                     101056.0                       179210.51
# 34    2023-11                      90891.0                       160284.57
# 35    2023-12                     172045.0                       490116.49
# 36    2024-01                      31757.0                       228201.82
# 37    2024-02                      51621.0                       165928.33
# 38    2024-03                      39950.0                       312487.00
# 39    2024-04                      28153.0                       101333.52
# 40    2024-05                      92444.0                        80485.36
# 41    2024-06                      20874.0                       208182.44
# 42    2024-07                     113688.0                       347551.70
# 43    2024-08                      99289.0                        94889.58
# 44    2024-09                      36280.0                       112220.06
# 45    2024-10                      18833.0                       183620.74
# 46    2024-11                      14309.0                       170841.64
# 47    2024-12                      56187.0                       288113.38

# %% [markdown]
# **Pandas display settings to show full dataframe**

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
print("\n== Alerts in Tabular Form ==")
print(alerts_df)
# Out:
# == Alerts in Tabular Form ==
#            Date           Location        Alert Type  \
# 0    2021-09-23     Rio Grande, BR   LOW UTILIZATION
# 1    2022-08-26  Uttar Pradesh, IN  HIGH UTILIZATION
# 2    2022-12-15      Karnataka, IN   LOW UTILIZATION
# 3    2021-06-09      Sao Paulo, BR  HIGH UTILIZATION
# 4    2023-01-14      Sao Paulo, BR  HIGH UTILIZATION
# 5    2023-11-27      Karnataka, IN  HIGH UTILIZATION
# 6    2023-09-10    Maharashtra, IN  HIGH UTILIZATION
# 7    2021-06-02      Rotterdam, NL  HIGH UTILIZATION
# 8    2021-12-17      Sao Paulo, BR  HIGH UTILIZATION
# 9    2021-03-26      Rotterdam, NL   LOW UTILIZATION
# 10   2022-02-20      Rotterdam, NL  HIGH UTILIZATION
# 11   2022-09-29      Karnataka, IN  HIGH UTILIZATION
# 12   2023-11-19       New York, US   LOW UTILIZATION
# 13   2023-08-03    Maharashtra, IN   LOW UTILIZATION
# 14   2024-06-12  Uttar Pradesh, IN   LOW UTILIZATION
# 15   2022-11-06  Uttar Pradesh, IN   LOW UTILIZATION
# 16   2023-01-30    Maharashtra, IN  HIGH UTILIZATION
# 17   2022-06-23  Uttar Pradesh, IN  HIGH UTILIZATION
# 18   2024-05-19       New York, US  HIGH UTILIZATION
# 19   2024-02-07  Uttar Pradesh, IN   LOW UTILIZATION
# 20   2024-03-13      Sao Paulo, BR   LOW UTILIZATION
# 21   2022-12-29      Karnataka, IN  HIGH UTILIZATION
# 22   2022-11-18  Uttar Pradesh, IN  HIGH UTILIZATION
# 23   2021-01-28  Uttar Pradesh, IN  HIGH UTILIZATION
# 24   2021-12-16       New York, US  HIGH UTILIZATION
# 25   2022-04-29      Sao Paulo, BR   LOW UTILIZATION
# 26   2022-08-30  Uttar Pradesh, IN  HIGH UTILIZATION
# 27   2024-09-13     Rio Grande, BR   LOW UTILIZATION
# 28   2021-12-10       New York, US   LOW UTILIZATION
# 29   2024-07-07      Sao Paulo, BR  HIGH UTILIZATION
# 30   2021-09-15     Rio Grande, BR   LOW UTILIZATION
# 31   2023-12-28      Karnataka, IN   LOW UTILIZATION
# 32   2022-10-23  Uttar Pradesh, IN  HIGH UTILIZATION
# 33   2024-08-11       New York, US   LOW UTILIZATION
# 34   2023-06-19      Rotterdam, NL   LOW UTILIZATION
# 35   2024-09-03      Rotterdam, NL  HIGH UTILIZATION
# 36   2023-12-28  Uttar Pradesh, IN   LOW UTILIZATION
# 37   2023-04-02       New York, US   LOW UTILIZATION
# 38   2024-04-15  Uttar Pradesh, IN   LOW UTILIZATION
# 39   2021-07-29      Sao Paulo, BR   LOW UTILIZATION
# 40   2024-03-12       New York, US  HIGH UTILIZATION
# 41   2023-11-28      Karnataka, IN   LOW UTILIZATION
# 42   2021-03-22      Karnataka, IN   LOW UTILIZATION
# 43   2024-05-08    Maharashtra, IN   LOW UTILIZATION
# 44   2023-09-23     Rio Grande, BR  HIGH UTILIZATION
# 45   2023-07-16      Rotterdam, NL   LOW UTILIZATION
# 46   2023-11-16      Rotterdam, NL  HIGH UTILIZATION
# 47   2022-02-04    Maharashtra, IN  HIGH UTILIZATION
# 48   2021-02-25    Maharashtra, IN   LOW UTILIZATION
# 49   2022-10-31    Maharashtra, IN   LOW UTILIZATION
# 50   2023-12-23       New York, US  HIGH UTILIZATION
# 51   2023-05-13    Maharashtra, IN   LOW UTILIZATION
# 52   2023-07-01      Karnataka, IN   LOW UTILIZATION
# 53   2022-10-14      Karnataka, IN  HIGH UTILIZATION
# 54   2024-12-21     Rio Grande, BR   LOW UTILIZATION
# 55   2021-03-14      Rotterdam, NL   LOW UTILIZATION
# 56   2024-05-09      Rotterdam, NL   LOW UTILIZATION
# 57   2021-01-16      Rotterdam, NL  HIGH UTILIZATION
# 58   2024-07-25    Maharashtra, IN   LOW UTILIZATION
# 59   2021-08-01    Maharashtra, IN   LOW UTILIZATION
# 60   2021-10-29       New York, US  HIGH UTILIZATION
# 61   2023-12-15  Uttar Pradesh, IN  HIGH UTILIZATION
# 62   2024-07-18     Rio Grande, BR   LOW UTILIZATION
# 63   2024-12-11     Rio Grande, BR  HIGH UTILIZATION
# 64   2021-06-25     Rio Grande, BR   LOW UTILIZATION
# 65   2023-04-19     Rio Grande, BR   LOW UTILIZATION
# 66   2021-10-11       New York, US   LOW UTILIZATION
# 67   2023-05-03       New York, US   LOW UTILIZATION
# 68   2023-04-14      Sao Paulo, BR   LOW UTILIZATION
# 69   2021-09-08      Sao Paulo, BR  HIGH UTILIZATION
# 70   2022-12-29    Maharashtra, IN  HIGH UTILIZATION
# 71   2022-12-21      Rotterdam, NL  HIGH UTILIZATION
# 72   2022-02-12      Karnataka, IN  HIGH UTILIZATION
# 73   2024-11-21  Uttar Pradesh, IN  HIGH UTILIZATION
# 74   2024-05-08      Rotterdam, NL   LOW UTILIZATION
# 75   2021-08-19      Rotterdam, NL  HIGH UTILIZATION
# 76   2022-05-04  Uttar Pradesh, IN   LOW UTILIZATION
# 77   2021-02-03  Uttar Pradesh, IN   LOW UTILIZATION
# 78   2024-12-29      Sao Paulo, BR  HIGH UTILIZATION
# 79   2023-01-29  Uttar Pradesh, IN  HIGH UTILIZATION
# 80   2024-08-10    Maharashtra, IN   LOW UTILIZATION
# 81   2024-06-19    Maharashtra, IN   LOW UTILIZATION
# 82   2022-05-22  Uttar Pradesh, IN   LOW UTILIZATION
# 83   2024-02-11     Rio Grande, BR  HIGH UTILIZATION
# 84   2022-06-02      Karnataka, IN   LOW UTILIZATION
# 85   2021-04-29      Karnataka, IN  HIGH UTILIZATION
# 86   2024-08-02    Maharashtra, IN   LOW UTILIZATION
# 87   2022-03-17     Rio Grande, BR  HIGH UTILIZATION
# 88   2024-07-16  Uttar Pradesh, IN  HIGH UTILIZATION
# 89   2021-03-30       New York, US  HIGH UTILIZATION
# 90   2024-06-20     Rio Grande, BR  HIGH UTILIZATION
# 91   2021-04-30      Rotterdam, NL   LOW UTILIZATION
# 92   2022-01-03    Maharashtra, IN  HIGH UTILIZATION
# 93   2024-07-29      Rotterdam, NL   LOW UTILIZATION
# 94   2021-08-16      Rotterdam, NL   LOW UTILIZATION
# 95   2022-04-17  Uttar Pradesh, IN  HIGH UTILIZATION
# 96   2021-12-22     Rio Grande, BR  HIGH UTILIZATION
# 97   2024-01-05    Maharashtra, IN  HIGH UTILIZATION
# 98   2024-12-17    Maharashtra, IN  HIGH UTILIZATION
# 99   2021-10-16      Rotterdam, NL  HIGH UTILIZATION
# 100  2023-04-22      Karnataka, IN   LOW UTILIZATION
# 101  2022-07-21     Rio Grande, BR   LOW UTILIZATION
# 102  2023-12-19       New York, US  HIGH UTILIZATION
# 103  2024-03-02  Uttar Pradesh, IN   LOW UTILIZATION
# 104  2024-02-20      Rotterdam, NL   LOW UTILIZATION
# 105  2021-07-11    Maharashtra, IN   LOW UTILIZATION
# 106  2022-03-25  Uttar Pradesh, IN   LOW UTILIZATION
# 107  2021-06-26      Rotterdam, NL   LOW UTILIZATION
# 108  2021-03-07  Uttar Pradesh, IN  HIGH UTILIZATION
# 109  2022-10-14    Maharashtra, IN  HIGH UTILIZATION
# 110  2023-07-31      Karnataka, IN   LOW UTILIZATION
# 111  2021-07-16      Rotterdam, NL   LOW UTILIZATION
# 112  2022-05-09      Karnataka, IN   LOW UTILIZATION
# 113  2024-11-27  Uttar Pradesh, IN   LOW UTILIZATION
# 114  2022-06-18       New York, US   LOW UTILIZATION
# 115  2024-04-21       New York, US  HIGH UTILIZATION
# 116  2021-05-16      Rotterdam, NL   LOW UTILIZATION
# 117  2024-01-02    Maharashtra, IN  HIGH UTILIZATION
# 118  2024-02-14  Uttar Pradesh, IN   LOW UTILIZATION
# 119  2022-03-03      Karnataka, IN  HIGH UTILIZATION
# 120  2021-07-11     Rio Grande, BR  HIGH UTILIZATION
# 121  2023-03-22      Karnataka, IN  HIGH UTILIZATION
# 122  2022-05-19    Maharashtra, IN   LOW UTILIZATION
# 123  2024-06-27  Uttar Pradesh, IN   LOW UTILIZATION
# 124  2023-04-06       New York, US   LOW UTILIZATION
# 125  2024-05-29      Rotterdam, NL   LOW UTILIZATION
# 126  2021-03-27       New York, US   LOW UTILIZATION
# 127  2021-07-12    Maharashtra, IN   LOW UTILIZATION
# 128  2021-04-08      Rotterdam, NL  HIGH UTILIZATION
# 129  2022-10-18      Rotterdam, NL   LOW UTILIZATION
# 130  2024-06-14     Rio Grande, BR  HIGH UTILIZATION
# 131  2023-05-22       New York, US  HIGH UTILIZATION
# 132  2024-02-06      Karnataka, IN   LOW UTILIZATION
# 133  2021-10-10     Rio Grande, BR  HIGH UTILIZATION
# 134  2021-12-22     Rio Grande, BR   LOW UTILIZATION
# 135  2021-03-19      Sao Paulo, BR  HIGH UTILIZATION
# 136  2022-05-10      Rotterdam, NL  HIGH UTILIZATION
# 137  2023-06-22      Karnataka, IN  HIGH UTILIZATION
# 138  2022-03-11     Rio Grande, BR  HIGH UTILIZATION
# 139  2021-08-14      Karnataka, IN   LOW UTILIZATION
# 140  2023-04-25  Uttar Pradesh, IN   LOW UTILIZATION
# 141  2023-12-23    Maharashtra, IN  HIGH UTILIZATION
# 142  2023-05-03      Rotterdam, NL   LOW UTILIZATION
# 143  2021-01-03      Karnataka, IN  HIGH UTILIZATION
# 144  2022-08-12      Sao Paulo, BR   LOW UTILIZATION
# 145  2023-07-26     Rio Grande, BR  HIGH UTILIZATION
# 146  2022-10-23      Sao Paulo, BR  HIGH UTILIZATION
# 147  2024-02-20      Rotterdam, NL  HIGH UTILIZATION
# 148  2022-03-22      Sao Paulo, BR   LOW UTILIZATION
# 149  2024-10-31       New York, US  HIGH UTILIZATION
# 150  2023-03-06      Rotterdam, NL   LOW UTILIZATION
# 151  2024-01-16       New York, US   LOW UTILIZATION
# 152  2022-01-21    Maharashtra, IN   LOW UTILIZATION
# 153  2022-06-14  Uttar Pradesh, IN   LOW UTILIZATION
# 154  2023-05-25    Maharashtra, IN   LOW UTILIZATION
# 155  2023-10-16     Rio Grande, BR   LOW UTILIZATION
# 156  2022-01-20  Uttar Pradesh, IN   LOW UTILIZATION
# 157  2022-10-10      Karnataka, IN  HIGH UTILIZATION
# 158  2021-11-21      Rotterdam, NL   LOW UTILIZATION
# 159  2021-10-16     Rio Grande, BR  HIGH UTILIZATION
# 160  2024-05-27       New York, US   LOW UTILIZATION
# 161  2023-04-02    Maharashtra, IN   LOW UTILIZATION
# 162  2022-05-21  Uttar Pradesh, IN  HIGH UTILIZATION
# 163  2021-12-29    Maharashtra, IN  HIGH UTILIZATION
# 164  2022-06-04  Uttar Pradesh, IN  HIGH UTILIZATION
# 165  2024-02-18  Uttar Pradesh, IN   LOW UTILIZATION
# 166  2022-11-17      Rotterdam, NL  HIGH UTILIZATION
# 167  2024-07-06      Sao Paulo, BR  HIGH UTILIZATION
# 168  2023-02-19      Sao Paulo, BR   LOW UTILIZATION
#
#                         Reason
# 0      8.00% storage occupied.
# 1     82.00% storage occupied.
# 2     14.00% storage occupied.
# 3     94.00% storage occupied.
# 4     81.00% storage occupied.
# 5     89.00% storage occupied.
# 6     99.00% storage occupied.
# 7     86.00% storage occupied.
# 8     84.00% storage occupied.
# 9     16.00% storage occupied.
# 10    85.00% storage occupied.
# 11    92.00% storage occupied.
# 12     6.00% storage occupied.
# 13    17.00% storage occupied.
# 14     0.00% storage occupied.
# 15     6.00% storage occupied.
# 16    91.00% storage occupied.
# 17    81.00% storage occupied.
# 18    97.00% storage occupied.
# 19    11.00% storage occupied.
# 20     1.00% storage occupied.
# 21    85.00% storage occupied.
# 22    91.00% storage occupied.
# 23    89.00% storage occupied.
# 24    87.00% storage occupied.
# 25     4.00% storage occupied.
# 26    94.00% storage occupied.
# 27     0.00% storage occupied.
# 28     0.00% storage occupied.
# 29    95.00% storage occupied.
# 30     1.00% storage occupied.
# 31    12.00% storage occupied.
# 32    92.00% storage occupied.
# 33     3.00% storage occupied.
# 34    13.00% storage occupied.
# 35    98.00% storage occupied.
# 36     6.00% storage occupied.
# 37    12.00% storage occupied.
# 38     1.00% storage occupied.
# 39    16.00% storage occupied.
# 40    95.00% storage occupied.
# 41     8.00% storage occupied.
# 42     0.00% storage occupied.
# 43     4.00% storage occupied.
# 44    94.00% storage occupied.
# 45     7.00% storage occupied.
# 46    86.00% storage occupied.
# 47    96.00% storage occupied.
# 48     7.00% storage occupied.
# 49     5.00% storage occupied.
# 50    82.00% storage occupied.
# 51    12.00% storage occupied.
# 52     3.00% storage occupied.
# 53    90.00% storage occupied.
# 54    12.00% storage occupied.
# 55    19.00% storage occupied.
# 56     4.00% storage occupied.
# 57    99.00% storage occupied.
# 58     8.00% storage occupied.
# 59    15.00% storage occupied.
# 60    97.00% storage occupied.
# 61    92.00% storage occupied.
# 62     1.00% storage occupied.
# 63    93.00% storage occupied.
# 64    11.00% storage occupied.
# 65     9.00% storage occupied.
# 66    10.00% storage occupied.
# 67     6.00% storage occupied.
# 68     8.00% storage occupied.
# 69    97.00% storage occupied.
# 70    91.00% storage occupied.
# 71    91.00% storage occupied.
# 72    84.00% storage occupied.
# 73    89.00% storage occupied.
# 74    19.00% storage occupied.
# 75    84.00% storage occupied.
# 76     5.00% storage occupied.
# 77     6.00% storage occupied.
# 78    87.00% storage occupied.
# 79    87.00% storage occupied.
# 80    19.00% storage occupied.
# 81    12.00% storage occupied.
# 82    19.00% storage occupied.
# 83    81.00% storage occupied.
# 84     6.00% storage occupied.
# 85    91.00% storage occupied.
# 86    12.00% storage occupied.
# 87    91.00% storage occupied.
# 88    94.00% storage occupied.
# 89    82.00% storage occupied.
# 90    91.00% storage occupied.
# 91     8.00% storage occupied.
# 92    93.00% storage occupied.
# 93    11.00% storage occupied.
# 94    19.00% storage occupied.
# 95    89.00% storage occupied.
# 96    82.00% storage occupied.
# 97    93.00% storage occupied.
# 98    82.00% storage occupied.
# 99    85.00% storage occupied.
# 100    2.00% storage occupied.
# 101   15.00% storage occupied.
# 102   83.00% storage occupied.
# 103    4.00% storage occupied.
# 104   19.00% storage occupied.
# 105    6.00% storage occupied.
# 106   11.00% storage occupied.
# 107   15.00% storage occupied.
# 108   87.00% storage occupied.
# 109   84.00% storage occupied.
# 110    0.00% storage occupied.
# 111   17.00% storage occupied.
# 112    3.00% storage occupied.
# 113    3.00% storage occupied.
# 114   15.00% storage occupied.
# 115   82.00% storage occupied.
# 116   19.00% storage occupied.
# 117   92.00% storage occupied.
# 118    5.00% storage occupied.
# 119  100.00% storage occupied.
# 120   95.00% storage occupied.
# 121  100.00% storage occupied.
# 122   19.00% storage occupied.
# 123    6.00% storage occupied.
# 124   10.00% storage occupied.
# 125   14.00% storage occupied.
# 126    6.00% storage occupied.
# 127   11.00% storage occupied.
# 128  100.00% storage occupied.
# 129   13.00% storage occupied.
# 130   86.00% storage occupied.
# 131   83.00% storage occupied.
# 132    2.00% storage occupied.
# 133   81.00% storage occupied.
# 134    4.00% storage occupied.
# 135   89.00% storage occupied.
# 136   93.00% storage occupied.
# 137  100.00% storage occupied.
# 138   96.00% storage occupied.
# 139    7.00% storage occupied.
# 140   16.00% storage occupied.
# 141   87.00% storage occupied.
# 142   14.00% storage occupied.
# 143   99.00% storage occupied.
# 144    9.00% storage occupied.
# 145   83.00% storage occupied.
# 146   97.00% storage occupied.
# 147   94.00% storage occupied.
# 148   13.00% storage occupied.
# 149   94.00% storage occupied.
# 150    2.00% storage occupied.
# 151    5.00% storage occupied.
# 152    8.00% storage occupied.
# 153    4.00% storage occupied.
# 154    2.00% storage occupied.
# 155   18.00% storage occupied.
# 156    3.00% storage occupied.
# 157   86.00% storage occupied.
# 158    4.00% storage occupied.
# 159   81.00% storage occupied.
# 160    5.00% storage occupied.
# 161    5.00% storage occupied.
# 162   93.00% storage occupied.
# 163   96.00% storage occupied.
# 164   91.00% storage occupied.
# 165   17.00% storage occupied.
# 166   89.00% storage occupied.
# 167   84.00% storage occupied.
# 168   12.00% storage occupied.

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %% [markdown]
# **Save results to files**

# %%
monthly_summary.to_csv("monthly_summary.csv", index=False)
alerts_df.to_csv("alerts.csv", index=False)
print("\nThe alerts have been saved to 'alerts.csv'. You can open it to view the full table.")
# Out:
# The alerts have been saved to 'alerts.csv'. You can open it to view the full table.
